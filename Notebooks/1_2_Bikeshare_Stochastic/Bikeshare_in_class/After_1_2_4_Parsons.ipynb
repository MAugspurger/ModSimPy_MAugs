# %% [markdown]
# # Parson's Problem Exercise
#
# <br>
#
#
#
# ---

# %% [markdown]
# ✅ ✅  Here is the code from notebook 1.2.4 that is used in the function below.  Before each function, write a comment (with a "#") that explains briefly what that function does.

# %%
import pandas as pd
import numpy.random as npr

bikeshare = pd.Series(dict(augie=10,moline=2),name='Number of Bikes')

def bike_to_moline():
    bikeshare.moline += 1
    bikeshare.augie -= 1

def bike_to_augie():
    bikeshare.moline -= 1
    bikeshare.augie += 1

def change_func(ptm, pta):
    if npr.random() < ptm:
        bike_to_moline()

    if npr.random() < pta:
        bike_to_augie()

# %% [markdown]
# ✅ ✅ This exercise is called a "Parson's Problem": in the code cell below are all of the necessary lines for a function `run_simulation` that runs a bikeshare simulation and the lines that call the function.  In addition, the comment lines for the function are included.
#
# <br>  The trick is that these lines are all out of order, and the necessary indents are removed.  Your job is to rearrange the lines so that the function works correctly.
#
# <br>  When complete the defined function should:
#
# 1. Create an empty `Series` object to hold the results.
#
# 2. Use a for loop to run `change_func` the number of times specified by `num_steps`, passing along the specified values of `p1` and `p2`.
#
# 3. After each step, it should save the number of bikes at augie in the `Series`.
#
# 4. After the for loop, it should plot the results.
#
# <br> To call the function, you will need to:
#
# 1. Create a state `Series` with the initial state of the system.
#
# 2. Call `run_simulation` with parameters `p1=0.5`, `p2=0.4`, and `num_steps=60`.  It should run the simulation and plot the results.
#
# Remember that you need to fix the indents as well as the line order.  Good luck!

# %%
# Test the function with the given values
results[0] = bikeshare.augie
run_simulation(0.5,0.6,60)
for i in range(num_steps):
# Plot the results and end the function
results.index.name = 'Time (m)'
# Run through time steps of the simulation and save the results
change_func(p1, p2)
results.plot(xlabel=results.index.name, ylabel=results.name,
            title='Augie-Moline Bikeshare',
            legend=True);
results[i+1] = bikeshare.augie
return
def run_simulation(p1,p2,num_steps):
# Create the empty results Series and add the initial condition
results = pd.Series([], dtype=object)
bikeshare = pd.Series(dict(augie=10,moline=2),name='Number of Bikes')
results.name='Number of Bikes at Augie'
# Define the run_simulation function
