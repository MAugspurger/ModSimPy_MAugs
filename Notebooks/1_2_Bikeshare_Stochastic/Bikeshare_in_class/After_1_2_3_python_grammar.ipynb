# %% [markdown]
# ## Paying Attention to Python Grammar
#
# Coding is all about details: even a period `.` or a `:` has a particular meaning.  In this exercise, add documentation to this Bikeshare code.  Use the "Quick_Reference_Guide" to add an explanation every you are prompted by the comments (`#`).
#
# <br>
#
# In particular, focus on the *grammar*: use the Table of Contents of the Quick Reference Guide to help you explain the purpose that a period or a colon or an indentation is serving.

# %%
import pandas as pd
# Meaning of dot (in the following line)?
import numpy.random as npr

# %%
# Meaning of 'def'?
# Meaning of parentheses?
def change_func(ptm, pta):
    # Meaning of the indent of this line?
    # What type of data object is created by 'npr.random() < ptm'?  Look up '<'
    if npr.random() < ptm:
        # Meaning of the parentheses?
        print("Bike to Moline")
        # Meaning of the dot?
        bikeshare.moline += 1
        bikeshare.augie -= 1

    # Meaning of the colon?
    if npr.random() < pta:
        # Meaning of the indent of this line?
        print("Bike to Augie")
        bikeshare.moline -= 1
        bikeshare.augie += 1

# %%
# Meaning of the equal sign?
# Meaning of the brackets?
# Type of 'state'?
state = {'augie':10, 'moline': 2}
# Meaning of dot?
bikeshare = pd.Series(state,name='Number of Bikes')
# Meaning of the quotation marks?
bikeshare.index.name = 'Location'

# %%
# Meaning of the parentheses?  Why no 'def' here?
change_func(0.5,0.4)
# Meaning of the brackets?
print("There are", bikeshare[0], "bikes at Augie")
