# %% [markdown]
# ## Error Hunting

# %% [markdown]
# Each of the code cells below leads to an error.  Use the tools at your disposal to see if you can figure out what went wrong, and explain what you find.  Generally, try these strategies, roughly in this order:
#
# <br>
#
# * Read the last line of the error message
# * Find the line *in the code* that an arrow points to in the error message
# * Look carefully at that line in the code, and see if you see a syntax problem
# * Use an internet search to find out what the error message means
# * If you are getting weird values for a variable, or a variable is not being correctly assigned, you can add `print' statements in different places in the code.  These can tell you *where* in the code the wrong value appears.

# %% [markdown]
# ---
#
# ### Example 1

# %%
# Example 1
bikeshare = pd.Series(state,name='Number of Bikes')

# %% [markdown]
# 🟨 🟨 1. Explain the error in a text cell below this.  What was wrong, and how did you fix it?

# %% [markdown]
# ---
#
# ### Example 2

# %%
# Example 2
import pandas as pd
bikeshare = pd.Series(state,name='Number of Bikes')
state = dict(augie=10,moline=2)

# %% [markdown]
# 🟨 🟨 2. Explain the error in a text cell below this.  What was wrong, and how did you fix it?

# %% [markdown]
# ---
#
# ### Example 3

# %%
# Example 3
import pandas as pd
state = dict(augie=10,moline=2)
bikeshare = pd.Series(state,name='Number of Bikes')
if bikeshare.moline == 1
    bikeshare.augie +- 1
bikeshare.augie

# %% [markdown]
# 🟨 🟨 3. Explain the error in a text cell below this.  What was wrong, and how did you fix it?

# %% [markdown]
# ---
#
# ### Example 4
#
# This next one doesn't produce an error message, but it produces the wrong answer.  Add a print statements to find out where the problem is: where is the value of `bikeshare.augie` correct or incorrect?  Does the code successfully make it inside the loop?

# %%
# Example 4
import pandas as pd
state = dict(augie=10,moline=2)
bikeshare = pd.Series(state,name='Number of Bikes')
if bikeshare.moline > 1:
    bikeshare.augie +- 1
bikeshare.augie

# %% [markdown]
# 🟨 🟨 4. Explain the error in a text cell below this.  What was wrong, and how did you fix it?

# %% [markdown]
# ---
# ### Example 5
#
# This produces an error specific to the Series.  Search for the error (with the phrase "Pandas Series") to see what went wrong.

# %%
# Example 5
import pandas as pd
state = dict(augie=10,moline=2)
bikeshare = pd.Series(state,name='Number of Bikes')
if bikeshare.moline > 1:
    bikeshare.augie += 1
bikeshare.name

# %% [markdown]
# 🟨 🟨 5. Explain the error in a text cell below this.  What was wrong, and how did you fix it?
